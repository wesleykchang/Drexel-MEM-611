# %% [markdown]
# ## Session 9
#
# Zoom link: https://drexel.zoom.us/rec/share/_UlpvzeZrwoD3vPOZccG64zWOoZ6-2WMcSjZ0DF2v4khKcn15aTmq4waj4Da0mLr.ZuEk-mkmNedsVJoJ
# Passcode: @7q+9%xV
#
#
# ### Laplace Transforms (Ch. 8 Yener and Kakac)
#
# From last time:
#
# $$\overline{f} (p)\ =\ \mathscr{L} (f(t))\ =\ \int _0^\infty e^{-pt} f(t) dt $$
#
# If this integral converges for some values of p, it is the Laplace transform of f(t). otherwise, the Laplace transform does not exist
#
# ### Example
#
# let f(t) = 1 when t > 0
#
# $$\mathscr{L} (1)\ =\ \int _0^\infty e^{-pt} dt\ =\ 1/p\ (p>0)  $$
#
# ### Example
#
# if f(t) = t when t > 0
#
# $$\mathscr{L} (t)\ =\ \int _0^\infty e^{-pt}t dt\ =\ 1/p^2\ (p>0)  $$
#
# ### Example
#
# if $$f(t)\ =\ e^{\alpha t}$$
#
# $$\mathscr{L} (t)\ =\ \int _0^\infty e^{-pt}e^{\alpha t} dt\ =\ 1/(p-\alpha)\ (p>\alpha)   $$
#
# ### Example: derivatives
#
# $$\mathscr{L} (f'(t))\ =\ \int _0^\infty e^{-pt} f'(t) dt $$
#
# $$=\ \int _0^\infty e^{-pt} f'(t) dt $$
#
# integration by parts, $$u\ =\ e^{-pt},\ dv\ =\ f'(t)dt$$
#
# $$e^{-pt}*f(t) |_0^{\infty}\ -\ \int _0^{\infty} f(t)*(-p)*e^{-pt}dt $$
#
# $$[0\ -\ 1*f(0)]\ +\ p*\int _0^{\infty} f(t)*e^{-pt}dt $$
#
# $$-f(0)\ +\ p*\overline{F}(p) $$
#
# ### Example: 1D heat conduction
#
# $$\frac{d^2T}{dx^2}\ =\ \frac{1}{\alpha}\frac{dT}{dt} $$
#
# $$T(x,0)\ =\ T_i $$
# $$\frac{dT(0,t)}{dx}\ =\ 0,\ T(L,t)\ =\ T_w $$
#
# $$\mathscr{L} {\frac{d^2T}{dx^2}}\ =\ \frac{1}{\alpha} \mathscr{L}\frac{dT}{dt}  $$
#
# $$\mathscr{L}{\frac{d^2T}{dx^2}}\ =\ \frac{d^2\overline{T}}{dx^2} $$
#
# $$\mathscr{L}(\frac{dT}{dt})\ =\ p\overline{T}(x,p)\ -\ T_i $$
#
# $$\frac{d^2\overline{T}}{dx^2}\ =\  \frac{1}{\alpha}(p\overline{T}\ -\ T_i) $$
#
# as this is an ODE:
#
# $$\overline{T}(x,p)\ =\ c_1*cosh(mx)\ +\ c_2*sinh(mx)\ +\ T_i/p $$
#
# take Laplace transform of boundary conditions:
# $$\mathscr{L}(T(L,t))\ =\ \mathscr{L}(T_w)\ =\ T_w/p$$
# $$\mathscr{L}(\frac{dT(0,t)}{dx})\ =\ d/dx(\overline{T}(0,p)) = 0$$
#
# plugging in the boundary conditions to solve for constants:
# $$c_2\ =\ 0 $$
# $$c_1\ =\ \frac{T_w\ -\ T_i}{p*cosh(mL)} $$
#
# therefore, solution is:
# $$\overline{T}(x,p)\ =\ T_i/p\ -\ (T_i\ - T_w)\frac{cosh(mx)}{p*cosh(mL)} $$
#
# now invert back to T(x,t):
#
# $$T(x,t)\ =\ T_i*\mathscr{L}^{-1}(1/p)\ -\ (T_i\ -\ T_w)\mathscr{L}^{-1}(\frac{cosh(mx)}{p*cosh(mL)}) $$
#
# checking tables:
#
# $$\mathscr{L}^{-1}(1/p)\ =\ 1 $$
#
# $$\mathscr{L}^{-1}(\frac{cosh(mx)}{p*cosh(mL)})\ =\ 1\ +\ \frac{4}{\pi} \sum _{n=1}^{\infty} \frac{(-1)^{n}}{(2n-1)} *e^{-(2n-1)^{2}*\pi^2*\alpha*t/L^2}*cos((2n-1)*\pi*x/2L) $$
#
# $$T(x,t)\ =\ T_i\ -\ (T_i\ -\ T_w)*(1\ +\ \frac{4}{\pi} \sum _{n=1}^{\infty} \frac{(-1)^{n}}{(2n-1)} *e^{-(2n-1)^{2}\pi^{2}\alpha t/L^2}*cos((2n-1)\pi x/2L) ) $$

# %% [markdown]
# ### Another Laplace transform example
#
# Consider a semi-infinite solid initially at temperature T_i. At times t >= 0, the surface at x = 0 is exposed to a fluid at temperature T_inf. Obtain an expression for the unsteady-state temperature distribution for times t > 0.
#
# (1) Draw schematic and write out general equation.
#
# $$\frac{d^2T}{dx^2}\ =\ \frac{1}{\alpha}\frac{dT}{dt} $$
#
# boundary conditions
#
# $$T(x,0)\ =\ T_i $$
#
# $$-k \frac{dT}{dx}|_{x=0}\ =\ h*[T_\infty\ -\ T(0,t)] $$
#
# $$T(x->\infty, t)\ =\ T_i $$
#
# (2) Apply Laplace transform on equation and boundary conditions
#
# $$\frac{d^2 \overline{T}}{dx^2}\ -\ \frac{p}{\alpha}\overline{T}(x,p)\ =\ -1/\alpha T_i $$
#
# $$-k \frac{d\overline{T}}{dx^2}_{x=0}\ =\ h*[1/p * T_\infty\ -\ \overline{T}(0,p)] $$
#
# (3) Solve the Laplace transformed equation
#
# Since it is in a recognizable ODE form
#
# $$\overline{T}(x,p)\ =\ A*e^{mx}\ +\ B*e^{-mx}\ +\ T_i/p $$
#
# plugging in boundary equations
#
# $$A\ =\ 0 $$
#
# $$kmB\ =\ h*[T_\infty /p\ -\ B\ -\ T_i/p] $$
#
# $$\overline{T}(x,p)\ =\ T_i/p\ +\ h*(T_\infty\ -\ T_i)*e^{-mx}/[p(km+h)] $$
#
# (4) Invert the Laplace transform
#
# $$T(x,t)\ =\ T_i\ +\ (T_\infty\ -\ T_i)h/k * \mathscr{L}^{-1}(e^{-mx}/(p*(m+h/k))) $$
#
# $$T(x,t)\ =\ T_i\ +\ (T_\infty\ -\ T_i)(erfc[x/2\sqrt{\alpha t}]\ -\ e^{hx/k\ +\ \alpha h^2 t/k^2} erfc[x/2\sqrt{\alpha t} + h/k\sqrt{\alpha t}]) $$

# %% [markdown]
# ### Similarity transforms
#
# From last time:
#
# (1) $$\theta\ =\ \frac{T\ -\ T_\infty}{T_i\ -\ T_\infty} $$
#
# (2) $$\eta\ =\ \frac{x}{(\alpha t)^{0.5}} $$
#
# $$\theta\ =\ \frac{1}{\sqrt{\pi}} \int_0^{\eta} e^{-\eta^2/4} d\eta\ =\ erf(\eta/2)$$
#
# ### Example: heat transfer and removal
#
# Heat is removed from the exposed surface of a semi-infinite region.
#
# $$q\ =\ -k\frac{dT}{dx}|_{x=0}\ =\ \frac{k(T_{\infty}\ -\ T_i)}{\sqrt{\alpha t}}\frac{d\theta}{d\eta}|_{\eta=0} $$
#
# differentiate
#
# $$q\ =\ \frac{k(T_{\infty}\ -\ T_i)}{\sqrt{\alpha t}} *\frac{e^{-\eta^2/4}}{\sqrt{\pi}}|_{\eta=0}\ = \ \frac{k(T_\infty\ -\ T_i)}{\sqrt{\pi \alpha t}}$$
#
# q decreases with the square root of time
#
# now say a specified heat  flux is applied at the boundary of a semi-infinite region
#
# we can differentiate the heat conduction equation w.r.t. x
#
# $$\alpha \frac{d^3 T}{dx^3}\ =\ \frac{d^2 T}{dt dx} $$
#
# substitute $$q\ = \ -k\frac{dT}{dx} $$
#
# $$\alpha \frac{d^2 q}{dx^2}\ =\ \frac{dq}{dt} $$
#
# this turns the local heat flux q into exactly the same form as the local temperature in the semi-infinite region. so solution should be same
#
# $$(q_w\ -\ q)/q_w\ =\ erf(x/2\sqrt{\alpha t}) $$
#
# $$T_w(t)\ =\ T_i\ +\ 2*q_w/k*\sqrt{\alpha t/\pi} $$

# %% [markdown]
# ## Course review
#
# ### Session 1 - intro to thermo and heat transfer
#
# Three modes of heat transfer
# - Conduction: process of heat transfer by molecular motion, along with flow of free electrons and lattice vibrations from regions of high temperature to regions of low temperature
# - Convection: process of heat transfer by movement of fluid
# - Radiation: process of heat transfer in the form of electromagnetic waves (i.e. materials emit radiation as a result of their temperature)
# *in practice, heat transfer occurs by a combination of all 3, but for simplicity we focus on each aspect separately
#
# What is conduction? **Heat transfer that occurs across a medium**
# - Temperature is generally associated with the energy of gas molecules in proximity to a reference point, and is related to both random translational motion and internal rotational and vibrational motions of molecules
#
# As $$ \Delta x \Rightarrow 0,\ q(x+\Delta x) = q(x) + dq/dx \Delta x $$ and $$ dq/dx = 0 $$, or q = constant
#
# **therefore, heat flow is constant if the two surface temperatures in a 1D steady state system (without any internal energy) is constant**
#
# Empirically, q is found to be directly proportional to surface area A and the temperature difference (T1 - T2), and inversely proportional to thickness L: $$ q \sim A*\frac{T_1 - T_2}{L} $$, or the instantaneous temperature change: $$ q = -kA \frac{dT}{dx} $$, which is Fourier's Law of Heat Conduction for a one-dimensional system.
#
# k has units of W/m-K and is called the **thermal conductivity**
#
# ### Session 3: General equations
#
# $$\nabla^2 T + \frac{\dot{q}}{k} = \frac{1}{\alpha} \frac{\delta T}{\delta t}$$
#
# thermal diffusivity: $$\alpha =\ \frac{k}{\rho c} $$
#
#
# Laplace Equation
#
# $$\nabla^2 T = 0$$
#
# Full general equation in cartesian coordinates
#
# $$\frac{\delta^2 T}{\delta x^2}\ +\ \frac{\delta^2 T}{\delta y^2}\ +\ \frac{\delta^2 T}{\delta z^2}\ =\ \frac{1}{\alpha}\ \frac{\delta T}{\delta t} $$
#
# ### Session 4: 1D Steady-state
#
# - One dimensional: heat transfer occurs only along a single coordinate axis
# - Steady-state: temperature at each point does not vary with time
#
# Remember, steady-state conditions with no internal energy source or sink means using the Laplace equation:
#
# $$\frac{d^2 T}{dx^2} =\ 0 $$
#
# Solving by integration:
#
# $$T(x)\ =\ C_1 x\ +\ C_2 $$
#
# Use the following boundary conditions:
#
# $$T(x=0)\ =\ T_1,\ T(x=L)\ =\ T_2$$
#
# $$C_2\ =\ T_1 $$
#
# $$C_1\ =\ \frac{T_2 - T_1}{L} $$
#
# Therefore:
#
# $$T(x)\ =\ (T_2\ -\ T_1)*x/L\ +\ T_1 $$
#
# ### Session 5: Separation of Variables and Unsteady-state Problems
#
# $$\frac{d^2 T}{dx^2}\ =\ \frac{1}{\alpha} \frac{dT}{dt}$$
#
# with boundary conditions $$T(x,0)\ =\ f(x)\\ T(0,t)\ =\ 0\\ T(L,t)\ =\ 0 $$
#
# as before, if we assume a solution exists that allows for separation of variables, then: $$T(x,t)\ =\ e^{-\alpha \lambda ^2 t}(A*sin(\lambda x)+B*cos(\lambda x)) $$
#
# 1. apply separation of variables
#
# $$T(x,t)\ =\ X(x)*\Gamma(t) $$
#
# $$\Gamma(t)\frac{d^2X}{dx^2}\ =\ 1/\alpha * X(x)* \frac{dT}{dt} = $$
#
# $$\frac{1}{X(x)}*\frac{d^2X}{dx^2} =  1/(\alpha *\Gamma(t))* \frac{dT}{dt}$$
#
# **remember when plugging in boundary conditions, T = X*Y so both functions X,Y must be considered!
#
# ### Session 6: Literature review of conductive heat transfer in commercial Li-ion batteries
#
# ### Session 7: Laplace and Similarity Transforms
#
# ### Session 8: Experimental measurements of thermal conductivity

# %% [markdown]
# ## Final Problem Set
#
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)
#
# 1. Consider a semi-infinite solid that is at a temperature T_i and subjected to a constant heat flux q" at x = 0 for times t >= 0. The Laplace transform of the temperature profile is calculated as shown:
#
# $$\overline{T}(x,p)\ =\ T_i/p\ + q''/k*\sqrt{\alpha/p}*e^{-x\sqrt{p/\alpha}}/p $$
#
# Given the table above, perform the inverse Laplace transform to obtain the temperature profile.
#
# 2. Consider an infinite solid medium bounded inside by a small cylindrical surface with radius r0, initial temperature T_i, and surface temperature T_s. Obtain a non-dimensionalized expression for the temperature profile and related boundary conditions using a similarity transform.
