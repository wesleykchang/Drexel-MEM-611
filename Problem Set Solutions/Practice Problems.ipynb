# %% [markdown]
# ### Additional Practice Problems
#
# 1. Solve the following problem using Laplace transforms.
#
# $\frac{\partial ^2 T}{\partial x^2}\ =\ \frac{1}{\alpha}\frac{\partial  T}{\partial t}$
#
# with initial condition $T(x,0)\ =\ T_i$ and boundary conditions $-k\frac{\partial T(x=0,t)}{\partial x}\ =\ q_w''$ and $lim_{x\rightarrow \infty} T(x,t)\ =\ T_i$
#
# a) what is the transformed equation?
#
# $\frac{d^2 \overline{T}}{dx^2}\ -\ \frac{p}{\alpha}\overline{T}(x,p)\ =\ -T_i/\alpha$
#
# b) what is the solution to the transformed equation?
#
# $\overline{T}(x,p)\ =\ c_1 e^{mx}\ +\ c_2 e^{-mx}\ +\ T_i/p$
#
# where $m\ =\ \sqrt{p/\alpha}$
#
# c) what are the constants after using the appropriately transformed boundary conditions?
#
# using the boundary condition at infinity: $c_1\ =\ 0$
#
# using the boundary condition at 0: $c_2\ =\ \frac{q_w''}{kp} \sqrt{\alpha/p}$
#
# d) what is the inverted equation? (use the table of Laplace transforms)
#
# $T(x,t)\ =\ T_i\ +
#  q_w''/k [2(\alpha t/\pi)^{1/2} e^{-x^2/4\alpha t}\ -\ x erfc(x/2 \sqrt{\alpha t})]$
#
# e) what is the final temperature profile?

# %% [markdown]
# 2.
#
# a) Given $\frac{\partial ^2 T}{\partial r^2}\ +\ \frac{2}{r}\frac{\partial T}{\partial r}\ =\ \frac{1}{\alpha}\frac{\partial T}{\partial t}$ with initial condition $T(r,0)\ =\ T_i$ and boundary conditions $T(0,t)\ =\ $ finite; and $k\frac{\partial T}{\partial r}|_{r=r0}\ =\ q_w''$, use an appropriate change of variable:
#
# $\theta\ =\ T\ -\ T_i$
#
# b) Transform the resulting equation:
#
# $\frac{d^2 \overline{\theta}}{dr^2}\ +\ 2/r \frac{d \overline{\theta}}{dr}\ =\ 1/\alpha [p \overline{T}\ -\ 0]$
#
# c) Solve the resulting equation:
#
# recognizing that the first two terms is equivalent to $\frac{d^2}{dr^2}(r \overline{\theta})$
#
#  $\frac{d^2}{dr^2}(r \overline{\theta})\ -\ \frac{r p \overline{\theta}}{\alpha}\ =\ 0$
#
#  this can be solved
#
# d) Find the constants after plugging in the appropriately transformed boundary conditions:
#
# *no need to take the inverse, as it is complicated

# %% [markdown]
# 3. Given a long solid cylinder with constant internal heat generation, constant thermal conductivity, with initial temperature at $T_i$ and temperature at the surface (r = r0) also at $T_i$:
#
#
# a) determine the general equation and boundary conditions for the unsteady state temperature:
#
# We're dealing with cylindrical coordinates with temperature a function of r. Hence:
#
# $\frac{\partial ^2 T}{\partial r^2}\ +\ 1/r \frac{\partial T}{\partial r}\ +\ \frac{\dot{q}}{k}\ =\ 1/\alpha \frac{\partial T}{\partial t}$
#
# boundary conditions:
#
# $T(0,t)\ =\ finite$
#
# $T(r_0, t)\ =\ T_i$
#
# initial condition: $T(r,t=0)\ =\ T_i$
#
# b) what change of variable would be appropriate?
#
# $\theta\ =\ T\ -\ T_i$
#
# c) perform a Laplace transform on the resulting equation
#
# $\mathscr{L}[  ]\ =\ \frac{d^2 \overline{\theta}}{dr^2}\ +\ 1/r \frac{d\overline{\theta}}{dr}\ +\ \dot{q}/kp\ =\ 1/\alpha [p \theta(r,p)\ -\ \overline{\theta}(r,0)]$

# %% [markdown]
# 4. Given $\frac{\partial ^2 T}{\partial r^2}\ +\ \frac{1}{r}\frac{\partial T}{\partial r}\ +\ \frac{\partial ^2 T}{\partial z^2}\ +\ \frac{\dot{q}(z)}{k}\ =\ 0$ with boundary conditions $T(0,z)\ =\ $ finite, $-k \frac{\partial T}{\partial r}|_{r=r0}\ =\ h(T(r,z)\ -\ T_\infty)$, $\frac{\partial T}{\partial z}|_{z=0}\ =\ \frac{\partial T}{\partial z}|_{z=L}\ =\ 0$
#
# a) what is an appropriate change of variable?
#
# b) given the boundary conditions, what is the appropriate Kernel function from Table 7.1?
#
# using the z-axis boundary conditions of the second kind, the appropriate Kernel function would be: $K_n(z)\ =\ \sqrt{2/L} cos(\lambda _n z)$ where $\lambda _n\ =\ n\pi/L$ for n = 1,2,3,...
#
# c) explain how you would take the integral transform? no need to do it, too complicated
#
# as in any integral transform, multiply each term of the general equation by the Kernel function and integrate from 0 to L. note since we are using $K_n(z)$, we integrate with respect to z, using the z-axis bounds from 0 to L. the resulting ODE should be a function of r only.

# %% [markdown]
# 5. Given a problem with boundary conditions $k\frac{\partial T}{\partial x}|_{x=0}\ =\ h_1 [T(0,t)\ -\ T_\infty (t)]$ and $-k\frac{\partial T}{\partial x}|_{x=L}\ =\ h_2[T(L,t)\ -\ T_\infty(t)]$
#
# what is the appropriate Kernel function?
#
# Recognize that both boundary conditions are of the third kind, and look up in Table 7.1:
#
# ![image.png](attachment:image.png)
